# %% [markdown]
# <font size="5"><b>Project Objectives:</b></font>
#
# <font size="3">- With different datasets, create and manipulate databases with SQLite3;</font>
#
# <font size="3">- Answer different kinds of business questions with queries;</font>
#
# <font size="3">- Create DataFrame objects as results from queries for a better visualization, this also make possible to start drawing inferences utilizing Pandas DataFrame functions.</font>

# %% [markdown]
# <font size="3"><b>Imports for data and database manipulation</b></font>

# %%
import pandas as pd
import sqlite3 as s3

# %% [markdown]
# <font size="4">Initial settings</font>

# %%
# Removing limitations by setting it to None to display all columns.
pd.set_option('display.max_columns', None)
# Removing limitations by setting it to None to display all rows.
pd.set_option('display.max_rows', None) 

# Function to return all the queries into dataframes
def query_results(cursor):
    # Get the results from the query
    results = cursor.fetchall()

    # Get the column names from the cursor description
    column_names = [description[0] for description in cursor.description]

    # Create the DataFrame from the results and column names
    df_results = pd.DataFrame(results, columns=column_names)

    # Query results
    return df_results

# %% [markdown]
# <font size="5"><b>#005 Dataset :  Sales - Products - Inventory Datasets</b></font>
# * Creating a database with three tables, with some primary and foreign keys.

# %%
df_sales = pd.read_csv('Sales.csv')
df_products = pd.read_csv('Products.csv')
df_inventory = pd.read_csv('Inventory.csv')
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

conn = s3.connect('Sales-products-inventory.sqlite')
cursor = conn.cursor()

# Salve os dados do Pandas no banco de dados SQLite3
df_sales.to_sql('Sales', conn, if_exists='replace', index=False)
df_products.to_sql('Products', conn, if_exists='replace', index=False)
df_inventory.to_sql('Inventory', conn, if_exists='replace', index=False)
# Out:
# 1000

# %%
print(df_sales.info())
df_sales.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SalesId    200000 non-null  int64
#  1   StoreId    200000 non-null  int64
#  2   ProductId  200000 non-null  int64
#  3   Date       200000 non-null  object
#  4   UnitPrice  200000 non-null  float64
#  5   Quantity   200000 non-null  int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 9.2+ MB
# None
#    SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 0    82319    22726        590  2019-12-02     0.0525        93
# 1    15022    21754        390  2017-11-19     5.1100        28
# 2    11624    71053        883  2020-07-13     7.3675        33
# 3    63101    22914        658  2019-05-12     2.0825        76
# 4    29702    22623        632  2020-07-20     0.6475         8

# %%
print(df_products.info())
df_products.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductId    1000 non-null   float64
#  1   ProductName  1000 non-null   object
#  2   Supplier     1000 non-null   object
#  3   ProductCost  1000 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 31.4+ KB
# None
#    ProductId               ProductName         Supplier  ProductCost
# 0        1.0  Chocolate Bar - Smarties  National Stores         1.25

# %%
print(df_inventory.info())
df_inventory.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductId          1000 non-null   int64
#  1   StoreId            1000 non-null   int64
#  2   StoreName          999 non-null    object
#  3   Address            1000 non-null   object
#  4   neighborhood       1000 non-null   object
#  5   QuantityAvailable  1000 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB
# None
#    ProductId  StoreId        StoreName             Address neighborhood  \
# 0          1    85123  National Stores  9 Springview Point  Bolton Hill
#
#    QuantityAvailable
# 0                 11

# %% [markdown]
# <font size="4">Business Question: Finding the <b>first</b> and <b>last</b> sale date - Range of the sales records</font>

# %%
cursor.execute('''
SELECT *
FROM Sales
WHERE Date = (SELECT MIN(Date) FROM Sales)
   OR Date = (SELECT MAX(Date) FROM Sales)
LIMIT 2;
''')
query_results(cursor)
# Out:
#    SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 0    81057    22310        159  2020-12-30     0.8925        31
# 1    63931    22310         55  2017-01-01     4.4800        34

# %% [markdown]
# <font size="2"><b>First Sale Date</b>: 2017-01-01</font>
#
# <font size="2"><b>Last Sale Date</b>: 2020-12-30</font>

# %%
cursor.execute('''
SELECT CAST(JULIANDAY(MAX(Date)) - JULIANDAY(MIN(Date)) AS INTEGER) AS days_duration
FROM Sales;
''')

query_results(cursor)
# Out:
#    days_duration
# 0           1459

# %% [markdown]
# <font size="2">Number of Days Between the <b>First</b> and <b>Last</b> Sale Dates: <b>1459 days</b></font>

# %% [markdown]
# <font size="4">Business Question: Identifying the <b>10 Most Sold Products</b> from 2017 to 2020</font>

# %%
cursor.execute('''
SELECT
    strftime('%Y', date) AS year,
    strftime('%m', date) AS month,
    ProductId,
    ROUND(MAX(UnitPrice), 2) AS UnitPrice,
    SUM(Quantity) AS UnitsSold
FROM
    Sales
GROUP BY
    year,
    month,
    ProductId 
ORDER BY UnitsSold DESC
LIMIT 10
''')
query_results(cursor)
# Out:
#    year month  ProductId  UnitPrice  UnitsSold
# 0  2017    09        221       1.23        882
# 1  2017    11        869       4.71        873
# 2  2020    12        219       2.77        861
# 3  2018    06        899       1.09        817
# 4  2018    07        381       1.31        809
# 5  2019    08        848       3.34        795
# 6  2018    02        961       1.30        781
# 7  2018    01        575       3.06        777
# 8  2019    10        875       1.05        770
# 9  2017    01        639       2.91        763

# %% [markdown]
# <font size="4">Business Question: <b>Total</b> Sales Revenue <b>Each Year</b></font>

# %%
cursor.execute('''
SELECT 
    strftime('%Y', Date) AS year, 
    ROUND(SUM(UnitPrice * Quantity), 2) AS total_revenue_millions 
FROM 
    Sales 
GROUP BY 
    year 
ORDER BY 
    year;
''')
df_results = query_results(cursor)
df_results['total_revenue_millions'] = df_results['total_revenue_millions'].apply(lambda x: f'{x/1e6:.2f} millions')
df_results
# Out:
#    year total_revenue_millions
# 0  2017          8.37 millions
# 1  2018          8.43 millions
# 2  2019          8.25 millions
# 3  2020          8.33 millions

# %% [markdown]
# <font size="4">Business Question: <b>Top Selling</b> Products</font>

# %%
cursor.execute('''
SELECT
    ProductId,
    SUM(Quantity) AS total_units_sold
FROM Sales
GROUP BY ProductId
ORDER BY total_units_sold DESC
LIMIT 10;
''')
query_results(cursor)
# Out:
#    ProductId  total_units_sold
# 0        530             12937
# 1        392             12711
# 2        133             12459
# 3        262             12435
# 4        991             12363
# 5        603             12361
# 6        837             12167
# 7        345             12068
# 8        668             12051
# 9        892             12035

# %% [markdown]
# <font size="4">Business Question: Average Unit Price</font>

# %%
cursor.execute('''
SELECT AVG(UnitPrice) AS average_unit_price
FROM Sales;
''')
query_results(cursor)
# Out:
#    average_unit_price
# 0            3.313406

# %% [markdown]
# <font size="4">Business Question: Store with Highest Revenue</font>

# %%
cursor.execute('''
SELECT
    StoreId,
    SUM(UnitPrice * Quantity) AS total_revenue
FROM Sales
GROUP BY StoreId
ORDER BY total_revenue DESC
LIMIT 1;
''')

df_results = query_results(cursor)
df_results['total_revenue'] = df_results['total_revenue'].apply(lambda x: f'{x/1e6:.2f} millions')
df_results
# Out:
#    StoreId  total_revenue
# 0    22748  1.02 millions

# %% [markdown]
# <font size="4">Business Question: <b>Most Common</b> Purchase <b>Size</b></font>

# %%
cursor.execute('''
SELECT
    Quantity,
    COUNT(*) AS frequency
FROM Sales
GROUP BY Quantity
ORDER BY frequency DESC
LIMIT 1;
''')
query_results(cursor)
# Out:
#    Quantity  frequency
# 0        73       2083

# %% [markdown]
# <font size="4">Business Question: Sales <b>Distribution</b> by <b>Month</b></font>

# %%
cursor.execute('''
SELECT
    strftime('%Y-%m', Date) AS year_month,
    SUM(UnitPrice * Quantity) AS monthly_revenue
FROM Sales
GROUP BY year_month
ORDER BY year_month;
''')
df_results = query_results(cursor)
df_results.head()
# Out:
#   year_month  monthly_revenue
# 0    2017-01      701304.6600
# 1    2017-02      634254.5300
# 2    2017-03      721855.8900
# 3    2017-04      700876.2425
# 4    2017-05      712926.7600

# %% [markdown]
# <font size="5"><b>#006 Dataset : Movie Dataset</b></font>

# %%
df_movie = pd.read_csv('Movie-Data.csv')
conn = s3.connect('Movie_Data.sqlite')
cursor = conn.cursor()

# Salve os dados do Pandas no banco de dados SQLite3
df_movie.to_sql('Movie_Data', conn, if_exists='replace', index=False)

print(df_movie.info())
df_movie.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie Title    508 non-null    object
#  1   Release Date   508 non-null    object
#  2   Wikipedia URL  508 non-null    object
#  3   Genre          508 non-null    object
#  4   Director (1)   508 non-null    object
#  5   Director (2)   41 non-null     object
#  6   Cast (1)       508 non-null    object
#  7   Cast (2)       503 non-null    object
#  8   Cast (3)       485 non-null    object
#  9   Cast (4)       452 non-null    object
#  10  Cast (5)       389 non-null    object
#  11  Budget         508 non-null    object
#  12  Revenue        508 non-null    object
# dtypes: object(13)
# memory usage: 51.7+ KB
# None
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# 2               https://en.wikipedia.org/wiki/2_Guns    Action
# 3  https://en.wikipedia.org/wiki/21_Jump_Street_(...    Comedy
# 4       https://en.wikipedia.org/wiki/22_Jump_Street    Action
#
#         Director (1)  Director (2)                 Cast (1)  \
# 0   Dan Trachtenberg           NaN  Mary Elizabeth Winstead
# 1        Michael Bay           NaN         James Badge Dale
# 2  Baltasar Kormákur           NaN            Mark Wahlberg
# 3          Phil Lord  Chris Miller               Jonah Hill
# 4          Phil Lord  Chris Miller           Channing Tatum
#
#             Cast (2)        Cast (3)         Cast (4)            Cast (5)  \
# 0       John Goodman  John Gallagher              NaN                 NaN
# 1     John Krasinski   Toby Stephens  Pablo Schreiber         Max Martini
# 2  Denzel Washington    Paula Patton      Bill Paxton  Edward James Olmos
# 3     Channing Tatum        Ice Cube      Brie Larson          Rob Riggle
# 4         Jonah Hill        Ice Cube              NaN                 NaN
#
#           Budget           Revenue
# 0  $15,000,000.00  $108,300,000.00
# 1  $45,000,000.00   $69,400,000.00
# 2  $61,000,000.00  $131,900,000.00
# 3  $55,000,000.00  $201,500,000.00
# 4  $84,500,000.00  $331,300,000.00

# %%
# Removing extra spaces on Budget column
cursor.execute('''
UPDATE Movie_Data
SET "Budget " = TRIM("Budget ")
''')
conn.commit()

# %%
# Renaming column
cursor.execute('''
ALTER TABLE Movie_Data RENAME COLUMN "Budget " TO "Budget"
''')
conn.commit()

# %% [markdown]
# <font size="4">Business Question: What is the <b>average budget and revenue </b> for movies in each genre?</b></font>

# %%
cursor.execute('''
SELECT
    Genre,
    AVG(CAST(REPLACE(Budget, '$', '') AS REAL)) AS average_budget,
    AVG(CAST(REPLACE(Revenue, '$', '') AS REAL)) AS average_revenue
FROM
    Movie_Data
GROUP BY
    Genre;
''')
query_results(cursor)
# Out:
#           Genre  average_budget  average_revenue
# 0        Action       82.783333       233.425000
# 1     Adventure       82.809524       308.238095
# 2     Animation       89.666667       276.000000
# 3     Biography       28.733333        58.333333
# 4        Comedy       39.857143       123.061224
# 5         Crime       30.391304        57.173913
# 6   Documentary       10.000000        68.000000
# 7         Drama       26.674157        80.573034
# 8        Family       78.416667       270.500000
# 9       Fantasy       91.000000       244.300000
# 10       Horror       14.604651        75.139535
# 11      Musical       40.250000       129.500000
# 12      Mystery       22.600000        96.400000
# 13    Religious       10.142857        36.428571
# 14      Romance       19.692308        53.230769
# 15       Sci-Fi       65.214286       255.035714
# 16     Thriller       33.187500       136.500000

# %% [markdown]
# <font size="4">Business Question: What are the <b>top 5 directors</b> who directed the <b>most</b> movies?</b></font>

# %%
cursor.execute('''
SELECT
    "Director (1)" AS director_name,
    COUNT("Movie Title") AS movie_count
FROM
    Movie_Data
GROUP BY
    director_name
ORDER BY
    movie_count DESC
LIMIT 5;
''')
query_results(cursor)
# Out:
#       director_name  movie_count
# 0        David Ayer            4
# 1       Woody Allen            3
# 2         Tim Story            3
# 3  Steven Spielberg            3
# 4        Shawn Levy            3

# %% [markdown]
# <font size="4">Business Question: How <b>many movies</b> fall into each budget range?</b></font>

# %%
cursor.execute('''
SELECT
    CASE
        WHEN CAST(REPLACE(Budget, '$', '') AS REAL) < 50000000 THEN 'Low Budget'
        WHEN CAST(REPLACE(Budget, '$', '') AS REAL) >= 50000000 AND CAST(REPLACE(Budget, '$', '') AS REAL) < 100000000 THEN 'Medium Budget'
        ELSE 'High Budget'
    END AS budget_range,
    COUNT(*) AS movie_count
FROM
    Movie_Data
GROUP BY
    budget_range;
''')
query_results(cursor)
# Out:
#   budget_range  movie_count
# 0   Low Budget          508

# %% [markdown]
# <font size="4">Business Question: What is the <b>average</b> revenue for movies directed by each director?</b></font>

# %%
cursor.execute('''
SELECT
    "Director (1)" AS director_name,
    AVG(CAST(REPLACE(Revenue, '$', '') AS REAL)) AS average_revenue
FROM
    Movie_Data
GROUP BY
    director_name
ORDER BY average_revenue DESC;
''')
query_results(cursor)
# Out:
#                   director_name  average_revenue
# 0                 Peter Jackson       956.000000
# 1                   Bill Condon       829.000000
# 2                    Tim Miller       782.000000
# 3                   Zack Snyder       770.000000
# 4                     Marc Webb       757.000000
# 5                  Eric Darnell       746.000000
# 6                 Anthony Russo       714.000000
# 7                   Matt Reeves       710.000000
# 8              Francis Lawrence       704.000000
# 9                  Chris Renaud       680.666667
# 10            Christopher Nolan       675.000000
# 11                 Bryan Singer       645.500000
# 12                 Dean DeBlois       621.000000
# 13                      Ang Lee       609.000000
# 14                Chris Sanders       587.000000
# 15                Steve Martino       561.500000
# 16                 Stephen Chow       553.000000
# 17                 Marc Forster       540.000000
# 18        Alejandro G. Iñárritu       533.000000
# 19               Gareth Edwards       529.000000
# 20                  Peyton Reed       519.000000
# 21          Jennifer Yuh Nelson       519.000000
# 22                 Ridley Scott       516.500000
# 23                   Justin Lin       515.500000
# 24              Carlos Saldanha       500.000000
# 25        Christopher McQuarrie       450.000000
# 26                  Alan Taylor       440.000000
# 27                 Duncan Jones       433.000000
# 28           Genndy Tartakovsky       415.500000
# 29               Matthew Vaughn       414.000000
# 30                James Mangold       414.000000
# 31           Jonathan Liebesman       399.000000
# 32               Rupert Sanders       396.000000
# 33                  Tim Johnson       386.000000
# 34                    Raman Hui       385.000000
# 35              Seth MacFarlane       382.500000
# 36                George Miller       378.000000
# 37              Olivier Megaton       376.000000
# 38                      Jon Chu       375.000000
# 39               Simon J. Smith       373.000000
# 40                   Doug Liman       370.000000
# 41                David Fincher       369.000000
# 42               Mike Thurmeier       368.000000
# 43             Darren Aronofsky       362.000000
# 44                    Gary Ross       357.500000
# 45                   Tony Scott       356.000000
# 46                  David Yates       352.000000
# 47              Louis Leterrier       351.000000
# 48                 Baz Luhrmann       351.000000
# 49                 Raja Gosnell       347.000000
# 50              Paul Greengrass       347.000000
# 51                  Clay Kaytis       346.000000
# 52                   Noam Murro       337.000000
# 53                  Brad Peyton       335.000000
# 54                    Phil Lord       333.666667
# 55                     Wes Ball       330.000000
# 56                 Paul Tibbitt       323.000000
# 57             Barry Sonnenfeld       321.500000
# 58                   Josh Boone       307.000000
# 59               Clint Eastwood       307.000000
# 60                 Peter Ramsey       306.000000
# 61                   Simon West       305.000000
# 62                   John Moore       304.000000
# 63                   Peter Berg       303.000000
# 64              Roland Emmerich       293.500000
# 65            Quentin Tarantino       290.000000
# 66                  Neil Burger       288.000000
# 67              Elizabeth Banks       287.000000
# 68              Joseph Kosinski       286.000000
# 69                  David Soren       282.000000
# 70             Steven Spielberg       276.333333
# 71                  Tony Gilroy       276.000000
# 72                  Rob Minkoff       275.000000
# 73                 Cody Cameron       274.000000
# 74                   Luc Besson       270.500000
# 75                  Chris Wedge       268.000000
# 76                    James Wan       266.000000
# 77             John R. Leonetti       256.000000
# 78                   Tom Hooper       252.500000
# 79                 Dennis Dugan       247.000000
# 80               Chris Columbus       244.000000
# 81           Guillermo del Toro       242.500000
# 82                 José Padilha       242.000000
# 83                  Jon Hurwitz       235.000000
# 84                  Walt Becker       234.000000
# 85                Morten Tyldum       233.000000
# 86                  Ben Affleck       232.000000
# 87                   David Ayer       228.000000
# 88                    Paul Feig       227.000000
# 89                Tommy Wirkola       226.000000
# 90                   Gary Shore       217.000000
# 91      Rawson Marshall Thurber       212.000000
# 92               Patrick Hughes       206.000000
# 93                  Scott Waugh       203.000000
# 94                Todd Phillips       202.000000
# 95             Thor Freudenthal       202.000000
# 96                 F. Gary Gray       201.000000
# 97                  Len Wiseman       198.000000
# 98                Thea Sharrock       196.000000
# 99             Takashi Yamazaki       196.000000
# 100             Nick Cassavetes       196.000000
# 101                Babak Najafi       195.000000
# 102              Neill Blomkamp       194.000000
# 103                Nancy Meyers       194.000000
# 104            Robert Schwentke       184.666667
# 105         Juan Antonio Bayona       180.000000
# 106               Larry Charles       179.000000
# 107         Paul W. S. Anderson       178.500000
# 108                Rian Johnson       176.000000
# 109                 Lee Daniels       176.000000
# 110                 Seth Gordon       174.000000
# 111                 Sean Anders       173.500000
# 112                Ryan Coogler       173.000000
# 113          M. Night Shyamalan       170.500000
# 114              Peter Farrelly       169.000000
# 115            David O. Russell       168.500000
# 116                  Shawn Levy       165.666667
# 117       Cedric Nicolas-Troyan       164.000000
# 118                Steven Quale       161.000000
# 119                  Jon M. Chu       161.000000
# 120                         McG       156.000000
# 121              George Clooney       155.000000
# 122               Rob Letterman       150.000000
# 123               Antoine Fuqua       148.333333
# 124                Dean Parisot       148.000000
# 125                  Josh Trank       147.000000
# 126           Andres Muschietti       146.000000
# 127               Gary Rydstrom       145.000000
# 128                 Alex Proyas       145.000000
# 129                  Dave Green       143.500000
# 130            Nicholas Stoller       143.333333
# 131              Ariel Schulman       142.000000
# 132                Breck Eisner       140.000000
# 133             Luke Greenfield       138.000000
# 134                  Tim Burton       137.000000
# 135             Kenneth Branagh       135.000000
# 136                  Will Gluck       133.000000
# 137                Ericson Core       133.000000
# 138                  Adam McKay       133.000000
# 139             Kathryn Bigelow       132.000000
# 140           Baltasar Kormákur       131.000000
# 141                  Tom Tykwer       130.000000
# 142          Jaume Collet-Serra       128.666667
# 143                  Joe Wright       128.000000
# 144               James Watkins       128.000000
# 145               Evan Goldberg       126.000000
# 146           David F. Sandberg       125.000000
# 147                   Tim Story       124.666667
# 148                   Jon Lucas       124.000000
# 149                  Peter Lord       123.000000
# 150                 James Marsh       123.000000
# 151                Wes Anderson       121.000000
# 152            Peter Lepeniotis       120.000000
# 153                  Daniel Lee       120.000000
# 154               Sergei Bodrov       114.000000
# 155               David Frankel       114.000000
# 156              Leigh Whannell       113.000000
# 157                Andy Fickman       113.000000
# 158             Robert Zemeckis       111.000000
# 159                 John Madden       111.000000
# 160                  Etan Cohen       111.000000
# 161             Daniel Espinosa       110.500000
# 162                 Jason Moore       110.000000
# 163                  J Blakeson       110.000000
# 164                 Guy Ritchie       109.000000
# 165             Anthony Stacchi       109.000000
# 166            Dan Trachtenberg       108.000000
# 167                Chris Butler       107.000000
# 168                Tarsem Singh       106.500000
# 169                 Mark Burton       106.000000
# 170             Ruben Fleischer       105.000000
# 171          John Francis Daley       104.000000
# 172               Wally Pfister       103.000000
# 173                Stiles White       103.000000
# 174            Denis Villeneuve       103.000000
# 175             Randall Wallace       101.000000
# 176                Frank Coraci       100.500000
# 177                 David Twohy       100.000000
# 178                 Scott Hicks        99.000000
# 179                Scott Cooper        99.000000
# 180          Jorge R. Gutierrez        99.000000
# 181              James DeMonaco        97.000000
# 182             Brian Helgeland        97.000000
# 183                   Gil Kenan        95.000000
# 184                Jodie Foster        93.000000
# 185                  Ron Howard        91.500000
# 186                Harald Zwart        90.000000
# 187                 Ben Falcone        89.000000
# 188                Tom McCarthy        88.000000
# 189                   Trish Sie        86.000000
# 190                  Kirk Jones        86.000000
# 191              Chad Stahelski        86.000000
# 192             Jonathan Levine        84.500000
# 193                David Dobkin        84.000000
# 194                Oliver Stone        83.000000
# 195              Angelina Jolie        83.000000
# 196          William Brent Bell        82.500000
# 197            Scott Derrickson        82.000000
# 198             Aleksander Bach        82.000000
# 199             Jeremy Garelick        79.000000
# 200           Timur Bekmambetov        78.500000
# 201                R. J. Cutler        78.000000
# 202                Ole Bornedal        78.000000
# 203             Gregory Plotkin        78.000000
# 204                 Michael Bay        77.500000
# 205                Joe Carnahan        77.000000
# 206                David Bowers        77.000000
# 207                 Cal Brunker        74.000000
# 208               Alex Kendrick        73.000000
# 209              Mark Neveldine        72.500000
# 210           Camille Delamarre        70.500000
# 211             Morgan Spurlock        68.000000
# 212               Brad Anderson        68.000000
# 213              Akiva Schaffer        68.000000
# 214               Phillip Noyce        67.000000
# 215         Christopher Spencer        67.000000
# 216              Malcolm D. Lee        66.500000
# 217           Steven Soderbergh        66.000000
# 218                Drew Goddard        66.000000
# 219                Ava DuVernay        66.000000
# 220                  S. Shankar        65.000000
# 221          Lee Toland Krieger        65.000000
# 222             Nima Nourizadeh        64.500000
# 223                   Peter Pau        64.000000
# 224             Levan Gabriadze        64.000000
# 225               Andrew Niccol        63.000000
# 226                Fede Alvarez        62.500000
# 227                John Crowley        62.000000
# 228                Simon Curtis        61.000000
# 229                Renny Harlin        61.000000
# 230           Michael Dougherty        61.000000
# 231             Lasse Hallström        61.000000
# 232         Richard LaGravenese        60.000000
# 233          David M. Rosenthal        60.000000
# 234               Joel Edgerton        59.000000
# 235               Adam Shankman        59.000000
# 236                 Woody Allen        58.333333
# 237                 Scott Frank        58.000000
# 238             Ric Roman Waugh        57.000000
# 239        Charles Martin Smith        57.000000
# 240                   Jay Roach        56.000000
# 241                 Ben Stiller        56.000000
# 242              Theodore Melfi        54.000000
# 243                  Sam Miller        54.000000
# 244              Bobby Farrelly        54.000000
# 245          Michael J. Bassett        52.000000
# 246            Jean-Marc Vallée        52.000000
# 247                  Ciaran Foy        52.000000
# 248               Anne Fletcher        51.000000
# 249             Peter Landesman        50.000000
# 250                  Dan Gilroy        50.000000
# 251           Anthony Hemingway        50.000000
# 252               Robert Lorenz        49.000000
# 253                  Doug Ellin        49.000000
# 254             Damien Chazelle        49.000000
# 255             Patricia Riggen        48.500000
# 256                  Tom Harper        48.000000
# 257             Taylor Hackford        48.000000
# 258                 Kim Ji-woon        48.000000
# 259                 Dan Bradley        48.000000
# 260             John Luessenhop        47.000000
# 261                 Henry Joost        47.000000
# 262            Derek Cianfrance        47.000000
# 263              Kevin Reynolds        46.000000
# 264                 Jon Favreau        46.000000
# 265                Edgar Wright        46.000000
# 266             Dexter Fletcher        46.000000
# 267                  Asger Leth        46.000000
# 268               Jake Schreier        44.500000
# 269           Richard Linklater        44.000000
# 270                  Boaz Yakin        44.000000
# 271              Garry Marshall        43.000000
# 272                  Ari Sandel        43.000000
# 273                Harold Cronk        42.500000
# 274              Michael Tiddes        42.000000
# 275             Nicholas Hytner        41.000000
# 276              Jonathan Demme        41.000000
# 277               Jessie Nelson        41.000000
# 278                Tom Gormican        40.000000
# 279                 Todd Haynes        40.000000
# 280               Robert Eggers        40.000000
# 281                Frank Miller        39.000000
# 282                 David Koepp        39.000000
# 283                  David Gelb        38.000000
# 284                  Jason Zada        37.000000
# 285              Bradley Parker        37.000000
# 286              Andrew Dominik        37.000000
# 287       Matt Bettinelli-Olpin        36.000000
# 288            Lenny Abrahamson        36.000000
# 289                  Ken Kwapis        36.000000
# 290         Julie Anne Robinson        36.000000
# 291                  John Wells        36.000000
# 292               Anton Corbijn        36.000000
# 293                Alex Garland        36.000000
# 294        Joshua Michael Stern        35.000000
# 295             Roger Donaldson        34.000000
# 296                   Rob Cohen        34.000000
# 297               Paul McGuigan        34.000000
# 298                 Tate Taylor        33.000000
# 299             Stephen Chbosky        33.000000
# 300              Dean Israelite        33.000000
# 301                Sarah Gavron        32.000000
# 302                James Mather        32.000000
# 303                  Gavin Hood        32.000000
# 304                   Billy Ray        32.000000
# 305              Stephen Frears        31.000000
# 306              Akiva Goldsman        31.000000
# 307               Thomas Carter        30.000000
# 308               Russell Crowe        30.000000
# 309           John Erick Dowdle        29.500000
# 310              James McTeigue        29.000000
# 311                Ivan Reitman        29.000000
# 312                 Danny Boyle        29.000000
# 313        Paul Thomas Anderson        28.000000
# 314               Vic Armstrong        27.000000
# 315               Travis Knight        27.000000
# 316                Don Scardino        27.000000
# 317       Scott Charles Stewart        26.000000
# 318                  Chris Rock        26.000000
# 319               Cameron Crowe        26.000000
# 320                Adam Wingard        26.000000
# 321                 Tyler Perry        25.500000
# 322           Nicole Holofcener        25.000000
# 323                Pierre Morel        24.000000
# 324               Glenn Ficarra        24.000000
# 325                  David Wain        24.000000
# 326             Stephen Hopkins        23.000000
# 327               John Hillcoat        23.000000
# 328                 Brad Furman        22.500000
# 329         Joel and Ethan Coen        22.000000
# 330               Brian Robbins        22.000000
# 331                Asif Kapadia        22.000000
# 332                 Walter Hill        21.000000
# 333                Benh Zeitlin        21.000000
# 334                         RZA        20.000000
# 335               Peter Atencio        20.000000
# 336                Ariel Vromen        19.500000
# 337               Sofia Coppola        19.000000
# 338                Michael Mann        19.000000
# 339                Jeff Nichols        19.000000
# 340           Niels Arden Oplev        18.000000
# 341           Michaël R. Roskam        18.000000
# 342              Ghaz Abu Bakar        17.000000
# 343  Alejandro Gómez Monteverde        17.000000
# 344           Mabrouk El Mechri        16.000000
# 345                 Burr Steers        16.000000
# 346                  Benson Lee        16.000000
# 347                 Rowan Joffé        15.000000
# 348                 Mark Waters        15.000000
# 349            Ed Gass-Donnelly        15.000000
# 350          The Erwin Brothers        14.000000
# 351                   Ken Scott        14.000000
# 352       Gina Prince-Bythewood        14.000000
# 353                 Dax Shepard        14.000000
# 354             Jerrica Cleland        12.000000
# 355          Jennifer Westfeldt        12.000000
# 356               J. C. Chandor        12.000000
# 357               Alex Kurtzman        12.000000
# 358                  Seth Rogen        11.000000
# 359               Noah Baumbach        11.000000
# 360               Josh Schwartz        11.000000
# 361            Courtney Solomon        11.000000
# 362                 Greg McLean        10.000000
# 363              Bille Woodruff        10.000000
# 364  Andrew Erwin and Jon Erwin        10.000000
# 365               Jorma Taccone         9.000000
# 366         Alfonso Gomez-Rejon         9.000000
# 367             Timo Vuorensola         8.000000
# 368              Marcus Dunstan         8.000000
# 369                Gus Van Sant         8.000000
# 370          David Gordon Green         8.000000
# 371                Dan Fogelman         8.000000
# 372               Curtis Hanson         8.000000
# 373                Gareth Evans         7.500000
# 374             Pascal Chaumeil         7.000000
# 375                 Jay Duplass         7.000000
# 376               Dennis Gansel         7.000000
# 377             Cyrus Nowrasteh         7.000000
# 378            Valérie Donzelli         6.000000
# 379                László Nemes         6.000000
# 380              James Ponsoldt         6.000000
# 381                  Diego Luna         6.000000
# 382               Anna Muylaert         6.000000
# 383                  Zach Braff         5.000000
# 384                   Nat Faxon         5.000000
# 385            James Vanderbilt         5.000000
# 386                    Ed Zwick         5.000000
# 387                Daniel Barnz         5.000000
# 388                     Sam Liu         4.000000
# 389              Michael Polish         4.000000
# 390         Deniz Gamze Ergüven         4.000000
# 391                  Rob Thomas         3.000000
# 392              Gavin O'Connor         3.000000
# 393                Carlo Carlei         3.000000
# 394             Bruno Podalydès         3.000000
# 395              Barry Levinson         3.000000
# 396              Zal Batmanglij         2.000000
# 397                Yann Demange         2.000000
# 398              William Eubank         2.000000
# 399               Scott McGehee         2.000000
# 400              Michael Cuesta         2.000000
# 401                Marc Abraham         2.000000
# 402               Jerry Jameson         2.000000
# 403           Dustin Marcellino         2.000000
# 404                 Ciro Guerra         2.000000
# 405                Angelo Pizzo         2.000000
# 406               William Riead         1.000000
# 407             Ryuhei Kitamura         1.000000
# 408             Matthew Diamond         1.000000
# 409                 Matt Hullum         1.000000
# 410                 Kevin Smith         1.000000
# 411         Jonathan Jakubowicz         1.000000
# 412           Grímur Hákonarson         1.000000
# 413                David Lowery         1.000000

# %% [markdown]
# <font size="4">Business Question: How <b>many movies</b> released each year?</b></font>

# %%
cursor.execute('''
SELECT
    STRFTIME('%Y', "Release Date") AS release_year,
    COUNT(*) AS movie_count
FROM
    Movie_Data
GROUP BY
    release_year
ORDER BY
    release_year;
''')
query_results(cursor)
# Out:
#   release_year  movie_count
# 0         2012          106
# 1         2013           85
# 2         2014          119
# 3         2015          124
# 4         2016           74
